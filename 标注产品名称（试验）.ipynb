# %%
cd C:\Users\小帅\Desktop\小牛看板\maverick-1月
# Out:
# C:\Users\小帅\Desktop\小牛看板\maverick-1月

# %%
import pandas as pd
import re  # 导入re模块

# 读取文档2
df2 = pd.read_excel('maverick-2024年1月-all（标注车型）.xlsx')

# 创建一个函数来标注商品
def annotate_product(row):
    title = str(row['商品标题'])  # 将商品标题转换为字符串类型
    title_lower = title.lower()
    
    # 定义用于匹配完整单词的正则表达式模式
    word_pattern = r'\b{}\b'.format

    # 初始化一个列表来收集所有匹配的类别
    matched_categories = []


    # 使用正则表达式匹配关键词，并将所有匹配的类别添加到列表中

    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("sidewall"), title_lower)) and (re.search(word_pattern("protector"), title_lower) or re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower)):
        matched_categories.append("后备箱两侧垫")

    if (re.search(word_pattern("tailgate mat"), title_lower) or re.search(word_pattern("tailgate pad"), title_lower) or re.search(word_pattern("tailgate liner"), title_lower)):
        matched_categories.append("尾门垫")
    if (re.search(word_pattern("bed mat"), title_lower) or re.search(word_pattern("bed liner"), title_lower) or re.search(word_pattern("bed mats"), title_lower)):
        matched_categories.append("后斗垫")

    if (re.search(word_pattern("tailgate"), title_lower)) and (re.search(word_pattern("mold"), title_lower) or re.search(word_pattern("mould"), title_lower) or re.search(word_pattern("molding"), title_lower) or re.search(word_pattern("moulding"), title_lower)) and (re.search(word_pattern("cap"), title_lower) or re.search(word_pattern("caps"), title_lower)) and (not re.search(word_pattern("clips"), title_lower)) :
        matched_categories.append("尾门护盖")

    if (re.search(word_pattern("bed rail"), title_lower)) and (re.search(word_pattern("cap"), title_lower) or re.search(word_pattern("caps"), title_lower)) and (not re.search(word_pattern("clips"), title_lower)) :
        matched_categories.append("护栏盖")
    if (re.search(word_pattern("tonneau covers"), title_lower) or re.search(word_pattern("tonneau cover"), title_lower)):
        matched_categories.append("后斗盖")
    if (re.search(word_pattern("bed extender"), title_lower)):
        matched_categories.append("后斗延长器")
    if (re.search(word_pattern("bed rails"), title_lower) or re.search(word_pattern("bed rail"), title_lower)):
        matched_categories.append("车斗护栏")
    if (re.search(word_pattern("tailgate"), title_lower) or re.search(word_pattern("bed"), title_lower)) and (re.search(word_pattern("ramp"), title_lower) or re.search(word_pattern("slides"), title_lower) or re.search(word_pattern("slide"), title_lower)) :
        matched_categories.append("尾门坡道")

    if (re.search(word_pattern("tent"), title_lower) or re.search(word_pattern("camping"), title_lower)):
        matched_categories.append("露营装备")
    if (re.search(word_pattern("skid plates"), title_lower) or re.search(word_pattern("skid plate"), title_lower)):
        matched_categories.append("车底防滑板")
    if (re.search(word_pattern("wheel well"), title_lower) or re.search(word_pattern("wheel-well"), title_lower) or re.search(word_pattern("inner fender"), title_lower)) and (re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("liner"), title_lower)) :
        matched_categories.append("车轮罩内衬")
    if (re.search(word_pattern("rocker panels"), title_lower) or re.search(word_pattern("rocker panel"), title_lower)):
        matched_categories.append("侧岩板")

    if (re.search(word_pattern("side skirts"), title_lower) or re.search(word_pattern("side skirt"), title_lower)):
        matched_categories.append("侧裙条")

    if (re.search(word_pattern("bed"), title_lower) or re.search(word_pattern("truck"), title_lower) or re.search(word_pattern("cargo"), title_lower)) and (re.search(word_pattern("dividers"), title_lower) or re.search(word_pattern("divider"), title_lower)) :
        matched_categories.append("货箱隔板")

    if (re.search(word_pattern("stake pocket"), title_lower) or re.search(word_pattern("bed hole"), title_lower)) and (re.search(word_pattern("covers"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("plug"), title_lower) or re.search(word_pattern("plugs"), title_lower)) :
        matched_categories.append("后斗插口盖")

    if (re.search(word_pattern("hood protector"), title_lower) or re.search(word_pattern("hood deflector"), title_lower) or re.search(word_pattern("bug deflector"), title_lower) or re.search(word_pattern("hood guard"), title_lower) or re.search(word_pattern("hood shield"), title_lower)):
        matched_categories.append("引擎盖护板")


    if (re.search(word_pattern("hinge"), title_lower)) and (re.search(word_pattern("cover"), title_lower)):
        matched_categories.append("铰链盖")



    if (re.search(word_pattern("cowling"), title_lower) or re.search(word_pattern("cowl"), title_lower) or re.search(word_pattern("corner guard"), title_lower) or re.search(word_pattern("corner guards"), title_lower)) and (re.search(word_pattern("armor"), title_lower) or re.search(word_pattern("cover"), title_lower)) :
        matched_categories.append("防弹罩护角")


    if (re.search(word_pattern("cowling"), title_lower) or re.search(word_pattern("cowl"), title_lower) or re.search(word_pattern("hood"), title_lower)) and (re.search(word_pattern("light"), title_lower)) and (re.search(word_pattern("mounting"), title_lower) or re.search(word_pattern("mount"), title_lower) or re.search(word_pattern("bracket"), title_lower) or re.search(word_pattern("brackets"), title_lower)) :
        matched_categories.append("机盖灯架")


    if (re.search(word_pattern("steering"), title_lower)) and (re.search(word_pattern("stabilizer"), title_lower)):
        matched_categories.append("转向稳定器")

    if (re.search(word_pattern("hood scoop"), title_lower) or re.search(word_pattern("hood scoops"), title_lower)):
        matched_categories.append("引擎盖进气冲压器")
    if (re.search(word_pattern("snow chains"), title_lower) or re.search(word_pattern("snow chain"), title_lower)):
        matched_categories.append("雪链")

    if (re.search(word_pattern("towing mirrors"), title_lower) or re.search(word_pattern("towing mirror"), title_lower)):
        matched_categories.append("拖车镜")

    if (re.search(word_pattern("mirror cover"), title_lower) or re.search(word_pattern("mirrors cover"), title_lower) or re.search(word_pattern("mirror protector"), title_lower) or re.search(word_pattern("mirror guard"), title_lower) or re.search(word_pattern("mirror guards"), title_lower)):
        matched_categories.append("后视镜罩")


    if (re.search(word_pattern("lug nuts"), title_lower) or re.search(word_pattern("lug nut"), title_lower)):
        matched_categories.append("轮毂螺帽")
    if (re.search(word_pattern("spoilers"), title_lower) or re.search(word_pattern("spoiler"), title_lower)):
        matched_categories.append("扰流板")

    if (re.search(word_pattern("spoilers"), title_lower) or re.search(word_pattern("spoiler"), title_lower)) and (re.search(word_pattern("wing"), title_lower)):
        matched_categories.append("尾翼")

    if (re.search(word_pattern("cargo cover"), title_lower) or re.search(word_pattern("security shield shade"), title_lower) or re.search(word_pattern("security shade cover shield"), title_lower)):
        matched_categories.append("遮物帘")
    if (re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("hooks"), title_lower) or re.search(word_pattern("hook"), title_lower)):
        matched_categories.append("后备箱挂钩")


    if (re.search(word_pattern("floor"), title_lower) or re.search(word_pattern("floorliner"), title_lower) or re.search(word_pattern("floorliners"), title_lower) or re.search(word_pattern("floormats"), title_lower) or re.search(word_pattern("row liners"), title_lower) or re.search(word_pattern("front liners"), title_lower) or re.search(word_pattern("row liner"), title_lower) or re.search(word_pattern("3rd row"), title_lower) or re.search(word_pattern("2nd row"), title_lower) or re.search(word_pattern("1st row"), title_lower) or re.search(word_pattern("front row"), title_lower) or re.search(word_pattern("3 rows"), title_lower) or re.search(word_pattern("slush"), title_lower) or re.search(word_pattern("smartliner"), title_lower) or re.search(word_pattern("husky"), title_lower) or re.search(word_pattern("tuxmat"), title_lower) or re.search(word_pattern("max liner"), title_lower) or re.search(word_pattern("all season"), title_lower) or re.search(word_pattern("all weather"), title_lower) or re.search(word_pattern("all-weather"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("floorliner"), title_lower) or re.search(word_pattern("floorliners"), title_lower) or re.search(word_pattern("smartliner"), title_lower)):
        matched_categories.append("脚垫")

    if (re.search(word_pattern("seat covers"), title_lower) or re.search(word_pattern("seat cover"), title_lower) or re.search(word_pattern("seat cushion"), title_lower) or re.search(word_pattern("seat cushions"), title_lower)) and (not re.search(word_pattern("back seat cover"), title_lower)) and (not re.search(word_pattern("back seat covers"), title_lower)):
        matched_categories.append("座椅套")

    if (re.search(word_pattern("backrest"), title_lower) or re.search(word_pattern("seat back"), title_lower) or re.search(word_pattern("seats back"), title_lower) or re.search(word_pattern("dog seat liner"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("covers"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("protector"), title_lower)):
        matched_categories.append("椅背垫")
    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower) or re.search(word_pattern("tub rail"), title_lower)) and (re.search(word_pattern("side covers"), title_lower) or re.search(word_pattern("side cover"), title_lower) or re.search(word_pattern("side protector"), title_lower) or re.search(word_pattern("rail cover"), title_lower) or re.search(word_pattern("edge protector"), title_lower)):
        matched_categories.append("后备箱侧沿护板")
    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("protector"), title_lower)):
        matched_categories.append("后备箱垫")

    if (re.search(word_pattern("front cargo"), title_lower) or re.search(word_pattern("front trunk"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("protector"), title_lower)):
        matched_categories.append("前备箱垫")

    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("protector"), title_lower)) and (re.search(word_pattern("lower"), title_lower) or re.search(word_pattern("liners"), title_lower)):
        matched_categories.append("货厢下层垫")

    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("liner"), title_lower) or re.search(word_pattern("liners"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("protector"), title_lower)) and (re.search(word_pattern("upper"), title_lower) or re.search(word_pattern("liners"), title_lower)):
        matched_categories.append("货厢上层垫")

    if (re.search(word_pattern("foot & front &rear trunk & backrest pad"), title_lower)):
        matched_categories.append("脚垫+椅背垫+后备箱垫")

    if (re.search(word_pattern("car cover"), title_lower) or re.search(word_pattern("car covers"), title_lower) or re.search(word_pattern("rain cover"), title_lower)):
        matched_categories.append("车衣")

    if (re.search(word_pattern("remote start"), title_lower) or re.search(word_pattern("remote starter"), title_lower)):
        matched_categories.append("远程启动")

    if (re.search(word_pattern("hood latches"), title_lower) or re.search(word_pattern("hood latch"), title_lower) or re.search(word_pattern("hood catch"), title_lower)):
        matched_categories.append("引擎盖门锁")


    if (re.search(word_pattern("vent cover"), title_lower) or re.search(word_pattern("vents cover"), title_lower) or re.search(word_pattern("vent covers"), title_lower) or re.search(word_pattern("vent trim"), title_lower) or re.search(word_pattern("vent protection"), title_lower) or re.search(word_pattern("vent protect"), title_lower) or re.search(word_pattern("vent protector"), title_lower) or re.search(word_pattern("grille inserts"), title_lower) or re.search(word_pattern("grille guard"), title_lower) or re.search(word_pattern("grille guards"), title_lower) or re.search(word_pattern("grille cover"), title_lower) or re.search(word_pattern("grille protection"), title_lower)) and (not re.search(word_pattern("bumper"), title_lower)) and (not re.search(word_pattern("brush guard"), title_lower)):
        matched_categories.append("进气格栅罩")

    if (re.search(word_pattern("charger"), title_lower) or re.search(word_pattern("charging"), title_lower)) and (re.search(word_pattern("cable"), title_lower)) and (re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("organizer"), title_lower)) :
        matched_categories.append("充电线缆整理器")

    if (re.search(word_pattern("snow cover"), title_lower) or re.search(word_pattern("snow covers"), title_lower) or re.search(word_pattern("snow protection"), title_lower) or re.search(word_pattern("frost cover"), title_lower) or re.search(word_pattern("windshield cover"), title_lower)):
        matched_categories.append("雪挡")


    if (re.search(word_pattern("rain"), title_lower) or re.search(word_pattern("side window"), title_lower)or re.search(word_pattern("rainwater"), title_lower)) and (re.search(word_pattern("guard"), title_lower) or re.search(word_pattern("guards"), title_lower) or re.search(word_pattern("deflectors"), title_lower) or re.search(word_pattern("deflector"), title_lower) or re.search(word_pattern("diverter"), title_lower) or re.search(word_pattern("diverters"), title_lower) or re.search(word_pattern("guard"), title_lower) or re.search(word_pattern("guards"), title_lower)):
        matched_categories.append("晴雨挡")


    if (re.search(word_pattern("roof"), title_lower) or re.search(word_pattern("top"), title_lower)) and (re.search(word_pattern("sunshade"), title_lower) or re.search(word_pattern("sunshades"), title_lower) or re.search(word_pattern("sun shade"), title_lower)):
        matched_categories.append("车顶遮阳")

    if (re.search(word_pattern("bimini"), title_lower) or re.search(word_pattern("bikini"), title_lower)) and (re.search(word_pattern("roof"), title_lower) or re.search(word_pattern("top"), title_lower)) and (re.search(word_pattern("sunshade"), title_lower) or re.search(word_pattern("sunshades"), title_lower) or re.search(word_pattern("sun shade"), title_lower)):
        matched_categories.append("遮阳顶")


    if (re.search(word_pattern("mud flaps"), title_lower) or re.search(word_pattern("mud flap"), title_lower) or re.search(word_pattern("mudguard"), title_lower) or re.search(word_pattern("mudguards"), title_lower) or re.search(word_pattern("mud guards"), title_lower) or re.search(word_pattern("splash guards"), title_lower)):
        matched_categories.append("挡泥板")

    if (re.search(word_pattern("fender flares"), title_lower) or re.search(word_pattern("fender flare"), title_lower)) and (not re.search(word_pattern("mud flap"), title_lower) or not re.search(word_pattern("mud guards"), title_lower)) :
        matched_categories.append("轮眉")
    if (re.search(word_pattern("hitch steps"), title_lower) or re.search(word_pattern("hitch step"), title_lower)) :
        matched_categories.append("拖车钩脚踏")


    if (re.search(word_pattern("foot pegs"), title_lower) or re.search(word_pattern("foot peg"), title_lower)) :
        matched_categories.append("前门铰链休息踏板")

    if (re.search(word_pattern("chrome"), title_lower) or re.search(word_pattern("delete"), title_lower)) :
        matched_categories.append("除铬装饰")

    if (re.search(word_pattern("valve"), title_lower) or re.search(word_pattern("hitch step"), title_lower)) and (re.search(word_pattern("cap"), title_lower) or re.search(word_pattern("caps"), title_lower)) :
        matched_categories.append("轮胎气门嘴")


    if (re.search(word_pattern("fuel filler"), title_lower) or re.search(word_pattern("gas cap"), title_lower) or re.search(word_pattern("fuel cap"), title_lower) or re.search(word_pattern("charging port"), title_lower) or re.search(word_pattern("charge port"), title_lower) or re.search(word_pattern("charger port"), title_lower)) and (re.search(word_pattern("cover"), title_lower)) :
        matched_categories.append("加油/充电口盖")


    if (re.search(word_pattern("shock absorbers"), title_lower) or re.search(word_pattern("shock absorber"), title_lower)) :
        matched_categories.append("减震器")

    if (re.search(word_pattern("spare tire"), title_lower) or re.search(word_pattern("spare wheel"), title_lower)) and (re.search(word_pattern("spacer"), title_lower)) :
        matched_categories.append("备胎垫片")

    if (re.search(word_pattern("spare tire"), title_lower) or re.search(word_pattern("spare wheel"), title_lower)) and (re.search(word_pattern("delete"), title_lower)) and (re.search(word_pattern("plate"), title_lower)) :
        matched_categories.append("备胎填充板")

    if (re.search(word_pattern("door screw"), title_lower)) and (re.search(word_pattern("protector"), title_lower)) and (re.search(word_pattern("cover"), title_lower)) :
        matched_categories.append("车门螺丝保护盖")


    if (re.search(word_pattern("windshield"), title_lower) or re.search(word_pattern("window"), title_lower) or re.search(word_pattern("windows"), title_lower)) and (re.search(word_pattern("sunshade"), title_lower) or re.search(word_pattern("shades"), title_lower) or re.search(word_pattern("sun shade"), title_lower) or re.search(word_pattern("sun visor"), title_lower) or re.search(word_pattern("sunshades"), title_lower)):
        matched_categories.append("遮阳挡")




    if (re.search(word_pattern("glove box"), title_lower)) and (re.search(word_pattern("dividers"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("partition"), title_lower)):
        matched_categories.append("手套箱隔板")
    if (re.search(word_pattern("dash"), title_lower) or re.search(word_pattern("dashboard"), title_lower) or re.search(word_pattern("behind screen"), title_lower)) and (re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("mount"), title_lower) or re.search(word_pattern("bracket"), title_lower) or re.search(word_pattern("panel"), title_lower)):
        matched_categories.append("仪表台支架")

    if (re.search(word_pattern("phone"), title_lower) or re.search(word_pattern("cellphone"), title_lower)) and (re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("mount"), title_lower) or re.search(word_pattern("bracket"), title_lower)):
        matched_categories.append("手机支架")

    if (re.search(word_pattern("dash"), title_lower) or re.search(word_pattern("air vent"), title_lower) or re.search(word_pattern("dashboard"), title_lower) or re.search(word_pattern("behind screen"), title_lower)) and (re.search(word_pattern("pad"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("mat"), title_lower) or re.search(word_pattern("mats"), title_lower) or re.search(word_pattern("storage"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organiser"), title_lower) or re.search(word_pattern("storage box"), title_lower)):
        matched_categories.append("仪表台储物垫")

    if (re.search(word_pattern("console"), title_lower) or re.search(word_pattern("shifter"), title_lower) or re.search(word_pattern("armrest"), title_lower) or re.search(word_pattern("gear shift"), title_lower) or re.search(word_pattern("transmission"), title_lower)) and (re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("pocket"), title_lower) or re.search(word_pattern("pockets"), title_lower) or re.search(word_pattern("organizers"), title_lower)  or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organiser"), title_lower) or re.search(word_pattern("storage box"), title_lower)):
        matched_categories.append("中控储物盒")

    if (re.search(word_pattern("underseat"), title_lower) or re.search(word_pattern("under seater"), title_lower) or re.search(word_pattern("under seat"), title_lower) or re.search(word_pattern("under-seat"), title_lower)) and (re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("pocket"), title_lower) or re.search(word_pattern("pockets"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organiser"), title_lower) or re.search(word_pattern("organizers"), title_lower) or re.search(word_pattern("storage box"), title_lower)):
        matched_categories.append("座椅下储物盒")

    if (re.search(word_pattern("tailgate"), title_lower) or re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("pocket"), title_lower) or re.search(word_pattern("pockets"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organiser"), title_lower) or re.search(word_pattern("organizers"), title_lower) or re.search(word_pattern("storage box"), title_lower) or re.search(word_pattern("storage boxs"), title_lower)):
        matched_categories.append("货厢储物盒")

    if (re.search(word_pattern("wheel well"), title_lower)) and (re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("pocket"), title_lower) or re.search(word_pattern("pockets"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organizers"), title_lower) or re.search(word_pattern("storage"), title_lower)):
        matched_categories.append("车轮凹槽储物箱")

    if (re.search(word_pattern("side door"), title_lower) or re.search(word_pattern("door side"), title_lower) or re.search(word_pattern("door handle"), title_lower) or re.search(word_pattern("grab tray"), title_lower) or re.search(word_pattern("front door"), title_lower) or re.search(word_pattern("grab bar"), title_lower) or re.search(word_pattern("grab handle"), title_lower) or re.search(word_pattern("door storage pockets"), title_lower) or re.search(word_pattern("door organizer"), title_lower)) and (re.search(word_pattern("pocket"), title_lower) or re.search(word_pattern("pockets"), title_lower) or re.search(word_pattern("organizer"), title_lower) or re.search(word_pattern("organiser"), title_lower) or re.search(word_pattern("storage"), title_lower) or re.search(word_pattern("trays"), title_lower) or re.search(word_pattern("tray"), title_lower)):
        matched_categories.append("车门拓展储物盒")

    if (re.search(word_pattern("molle"), title_lower)) and (re.search(word_pattern("panel"), title_lower) or re.search(word_pattern("panels"), title_lower) or re.search(word_pattern("grid"), title_lower)):
        matched_categories.append("molle面板")

    if (re.search(word_pattern("trash"), title_lower)) and (re.search(word_pattern("can"), title_lower)):
        matched_categories.append("垃圾桶")

    if (re.search(word_pattern("seatbelt"), title_lower) or re.search(word_pattern("headrest"), title_lower)) and (re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("hanger"), title_lower) or re.search(word_pattern("hook"), title_lower)):
        matched_categories.append("安全带引导架挂钩")

    if (re.search(word_pattern("armrest"), title_lower) or re.search(word_pattern("center console"), title_lower)) and (re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("cushion"), title_lower) or re.search(word_pattern("protector"), title_lower) or re.search(word_pattern("pad"), title_lower)) and (not re.search(word_pattern("screen"), title_lower)) :
        matched_categories.append("扶手箱套")


    if (re.search(word_pattern("speaker pods"), title_lower)):
        matched_categories.append("吊舱音响外壳")

    if (re.search(word_pattern("rear door"), title_lower) or re.search(word_pattern("tailgate"), title_lower)) and (re.search(word_pattern("table"), title_lower)):
        matched_categories.append("尾门折叠工作台")
    if (re.search(word_pattern("soft top"), title_lower)) and (re.search(word_pattern("window storage bag"), title_lower)):
        matched_categories.append("软顶窗户收纳包")

    if (re.search(word_pattern("snugtop cap"), title_lower) or re.search(word_pattern("snugtop caps"), title_lower) or re.search(word_pattern("canopies"), title_lower) or re.search(word_pattern("canopy"), title_lower) or re.search(word_pattern("toppers"), title_lower) or re.search(word_pattern("topper"), title_lower)):
        matched_categories.append("顶篷")

    if (re.search(word_pattern("tie-down"), title_lower) or re.search(word_pattern("tie down"), title_lower)) and (re.search(word_pattern("anchor"), title_lower) or re.search(word_pattern("anchors"), title_lower)):
        matched_categories.append("车斗锚栓")

    if (re.search(word_pattern("pinch weld covers"), title_lower) or re.search(word_pattern("pinch weld cover"), title_lower)):
        matched_categories.append("侧裙边")

    if (re.search(word_pattern("roof racks"), title_lower) or re.search(word_pattern("roof rack"), title_lower) or re.search(word_pattern("cross bars"), title_lower) or re.search(word_pattern("crossbars"), title_lower)  or re.search(word_pattern("cross bar"), title_lower) or re.search(word_pattern("bed rack"), title_lower) or re.search(word_pattern("bed racks"), title_lower)):
        matched_categories.append("行李架")
    if (re.search(word_pattern("console"), title_lower)) and (re.search(word_pattern("charging"), title_lower) or re.search(word_pattern("charger"), title_lower) or re.search(word_pattern("chargers"), title_lower)) and (re.search(word_pattern("pad"), title_lower) or re.search(word_pattern("tray"), title_lower) or re.search(word_pattern("mat"), title_lower)):
        matched_categories.append("中控充电板")
    if (re.search(word_pattern("running boards"), title_lower) or re.search(word_pattern("side step"), title_lower) or re.search(word_pattern("side steps"), title_lower) or re.search(word_pattern("nerf bars"), title_lower) or re.search(word_pattern("nerf bar"), title_lower) or re.search(word_pattern("step bars"), title_lower) or re.search(word_pattern("rock rails"), title_lower)or re.search(word_pattern("step rails"), title_lower)):
        matched_categories.append("岩轨踏板")
    if (re.search(word_pattern("powerstep"), title_lower) or re.search(word_pattern("power running boards"), title_lower) or re.search(word_pattern("power running board"), title_lower)):
        matched_categories.append("电动踏板")
    if (re.search(word_pattern("wiper blade"), title_lower) or re.search(word_pattern("wiper blades"), title_lower)):
        matched_categories.append("雨刷片")


    if (re.search(word_pattern("hard top"), title_lower) or re.search(word_pattern("hardtop"), title_lower) or re.search(word_pattern("roof top"), title_lower) or re.search(word_pattern("roof panel"), title_lower)) and (re.search(word_pattern("storage bag"), title_lower)):
        matched_categories.append("硬顶收纳包")
    if (re.search(word_pattern("door storage bags"), title_lower) or re.search(word_pattern("door storage bag"), title_lower) or re.search(word_pattern("door bag"), title_lower) or re.search(word_pattern("door bags"), title_lower)):
        matched_categories.append("车门收纳包")

    if (re.search(word_pattern("roll bar"), title_lower) or re.search(word_pattern("d-pillar"), title_lower)) and (re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("covers"), title_lower)):
        matched_categories.append("d柱护板")
    if (re.search(word_pattern("crash bar"), title_lower)) and (re.search(word_pattern("end caps"), title_lower) or re.search(word_pattern("end cap"), title_lower) or re.search(word_pattern("stopper cover"), title_lower)):
        matched_categories.append("前桥皮塞")


    if (re.search(word_pattern("tube door"), title_lower) or re.search(word_pattern("tube doors"), title_lower) or re.search(word_pattern("tubular doors"), title_lower) or re.search(word_pattern("half doors"), title_lower)):
        matched_categories.append("管门")
    if (re.search(word_pattern("winch"), title_lower)) and (re.search(word_pattern("bracket"), title_lower) or re.search(word_pattern("mount"), title_lower) or re.search(word_pattern("plate"), title_lower)):
        matched_categories.append("绞盘架")

    if (re.search(word_pattern("bull bar"), title_lower) or re.search(word_pattern("front bumper"), title_lower) or re.search(word_pattern("grille guard"), title_lower) or re.search(word_pattern("winch guard"), title_lower) or re.search(word_pattern("brush guard"), title_lower) or re.search(word_pattern("bumper guard"), title_lower)):
        matched_categories.append("小牛栏")

    if (re.search(word_pattern("front"), title_lower) or re.search(word_pattern("front"), title_lower) or re.search(word_pattern("shark"), title_lower)) and (re.search(word_pattern("grille"), title_lower) or re.search(word_pattern("grill"), title_lower)):
        matched_categories.append("前格栅")



    if (re.search(word_pattern("front lip"), title_lower) or re.search(word_pattern("bumper lip"), title_lower) or re.search(word_pattern("rear lip"), title_lower)):
        matched_categories.append("前后唇")

    if (re.search(word_pattern("bumper sill"), title_lower) or re.search(word_pattern("tailgate sill"), title_lower) or re.search(word_pattern("trunk sill"), title_lower) or re.search(word_pattern("trunk door sill"), title_lower) or re.search(word_pattern("bumper protector"), title_lower)):
        matched_categories.append("后护板")



    if (re.search(word_pattern("hitch"), title_lower) or re.search(word_pattern("tow hook"), title_lower) or re.search(word_pattern("tow hooks"), title_lower)):
        matched_categories.append("拖车挂钩")

    if (re.search(word_pattern("hitch"), title_lower) or re.search(word_pattern("tow hook"), title_lower) or re.search(word_pattern("tow hooks"), title_lower)) and  (re.search(word_pattern("covers"), title_lower) or re.search(word_pattern("cover"), title_lower)):
        matched_categories.append("拖钩保护套")

    if (re.search(word_pattern("air"), title_lower)) and (re.search(word_pattern("filters"), title_lower) or re.search(word_pattern("filter"), title_lower)):
        matched_categories.append("空气滤清器")

    if (re.search(word_pattern("air"), title_lower)) and (re.search(word_pattern("deflectors"), title_lower) or re.search(word_pattern("deflector"), title_lower)):
        matched_categories.append("气流偏导器")

    if (re.search(word_pattern("usb extender"), title_lower) or re.search(word_pattern("docking station"), title_lower) or re.search(word_pattern("usb hub"), title_lower) or re.search(word_pattern("charge ports"), title_lower)):
        matched_categories.append("usb拓展坞")

    if (re.search(word_pattern("transmission"), title_lower) or re.search(word_pattern("chassic"), title_lower) or re.search(word_pattern("gearbox"), title_lower)) and (re.search(word_pattern("skid plate"), title_lower) or re.search(word_pattern("splash shield"), title_lower) or re.search(word_pattern("guard"), title_lower)):
        matched_categories.append("变速箱下护板")

    if (re.search(word_pattern("door edge guards"), title_lower) or re.search(word_pattern("door sill"), title_lower) or re.search(word_pattern("door entry"), title_lower)):
        matched_categories.append("外置门槛条")

    if (re.search(word_pattern("tunnel"), title_lower)) and (re.search(word_pattern("door edge guards"), title_lower) or re.search(word_pattern("door sill"), title_lower) or re.search(word_pattern("door entry"), title_lower)):
        matched_categories.append("隧道门槛条")

    if (re.search(word_pattern("fuse box cover"), title_lower) or re.search(word_pattern("fuse box holder"), title_lower) or re.search(word_pattern("wire harness organizer"), title_lower) or re.search(word_pattern("fuse block"), title_lower) or re.search(word_pattern("fuse panel covers"), title_lower)):
        matched_categories.append("保险盒防水盖")
    if (re.search(word_pattern("foot rest"), title_lower) or re.search(word_pattern("foot pedal"), title_lower) or re.search(word_pattern("brake pedal"), title_lower) or re.search(word_pattern("pedal pads"), title_lower)  or re.search(word_pattern("pedal covers"), title_lower) or re.search(word_pattern("gas pedal"), title_lower)):
        matched_categories.append("休息踏板")

    if (re.search(word_pattern("license plate"), title_lower)) and (re.search(word_pattern("frame"), title_lower) or re.search(word_pattern("frames"), title_lower) or re.search(word_pattern("bracket"), title_lower) or re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("mount"), title_lower)):
        matched_categories.append("车牌架")
    if (re.search(word_pattern("hubcap"), title_lower) or re.search(word_pattern("hubcaps"), title_lower) or re.search(word_pattern("hub caps"), title_lower) or re.search(word_pattern("wheel skins"), title_lower) or re.search(word_pattern("wheel covers"), title_lower) or re.search(word_pattern("wheel cover"), title_lower)) and (not re.search(word_pattern("caps center"), title_lower) and not re.search(word_pattern("steering"), title_lower)):
        matched_categories.append("轮毂罩")

    if (re.search(word_pattern("center caps"), title_lower) or re.search(word_pattern("center cap"), title_lower)) :
        matched_categories.append("轮毂中心盖")

    if (re.search(word_pattern("jack"), title_lower)) and (re.search(word_pattern("pucks"), title_lower) or re.search(word_pattern("puck"), title_lower) or re.search(word_pattern("pads"), title_lower)  or re.search(word_pattern("pad"), title_lower) or re.search(word_pattern("adapter"), title_lower)): 
        matched_categories.append("千斤顶盖")

    if (re.search(word_pattern("steering wheel"), title_lower)) and (re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("covers"), title_lower)) and (not re.search(word_pattern("hubcaps"), title_lower) and not re.search(word_pattern("hub caps"), title_lower)):
        matched_categories.append("方向盘套") 

    if (re.search(word_pattern("key"), title_lower)) and (re.search(word_pattern("fob"), title_lower) or re.search(word_pattern("holder"), title_lower) or re.search(word_pattern("case"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("shell"), title_lower) or re.search(word_pattern("chain"), title_lower)):
        matched_categories.append("钥匙套") 

    if (re.search(word_pattern("emblem"), title_lower) or re.search(word_pattern("emblems"), title_lower) or re.search(word_pattern("stickers"), title_lower)  or re.search(word_pattern("sticker"), title_lower) or re.search(word_pattern("decals"), title_lower) or re.search(word_pattern("decal"), title_lower)):
        matched_categories.append("贴花") 

    if (re.search(word_pattern("seat back"), title_lower) or re.search(word_pattern("headrest"), title_lower)  or re.search(word_pattern("backseat"), title_lower)) and (re.search(word_pattern("hook"), title_lower) or re.search(word_pattern("hooks"), title_lower)):
        matched_categories.append("椅背挂钩") 

    if (re.search(word_pattern("sunglasses"), title_lower) or re.search(word_pattern("glasses"), title_lower)) and (re.search(word_pattern("case"), title_lower) or re.search(word_pattern("holder"), title_lower)):
        matched_categories.append("眼镜盒") 

    if (re.search(word_pattern("seat slide rail"), title_lower) or re.search(word_pattern("underseat"), title_lower)) and (re.search(word_pattern("pad"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("protector"), title_lower)):
        matched_categories.append("座椅滑轨盖") 

    if (re.search(word_pattern("charging"), title_lower) or re.search(word_pattern("charger"), title_lower) or re.search(word_pattern("ccs"), title_lower)) and (re.search(word_pattern("adaptor"), title_lower) or re.search(word_pattern("adapter"), title_lower) or re.search(word_pattern("converter"), title_lower)) and (not re.search(word_pattern("cable"), title_lower) and not re.search(word_pattern("organizer"), title_lower)):
        matched_categories.append("充电适配器") 


    if (re.search(word_pattern("grab handles"), title_lower) or re.search(word_pattern("grab handle"), title_lower) or re.search(word_pattern("grip handles"), title_lower) or re.search(word_pattern("grip handle"), title_lower)):
        matched_categories.append("抓手") 

    if (re.search(word_pattern("doors off"), title_lower) or re.search(word_pattern("door off"), title_lower)) and  (re.search(word_pattern("mirrors"), title_lower)):
        matched_categories.append("无门侧视镜") 

    if  (re.search(word_pattern("roof"), title_lower)) and (re.search(word_pattern("cargo netting"), title_lower) or re.search(word_pattern("cargo net"), title_lower) or re.search(word_pattern("hammock"), title_lower)):
        matched_categories.append("车顶吊床") 

    if (re.search(word_pattern("door handle wrap"), title_lower)):
        matched_categories.append("门把手贴花") 

    if (re.search(word_pattern("antenna"), title_lower)):
        matched_categories.append("天线顶盖") 

    if (re.search(word_pattern("caliper"), title_lower)) and (re.search(word_pattern("covers"), title_lower)):
        matched_categories.append("刹车钳盖") 


    if (re.search(word_pattern("louver"), title_lower) or re.search(word_pattern("louvers"), title_lower)) and (re.search(word_pattern("cover"), title_lower) or re.search(word_pattern("covers"), title_lower)):
        matched_categories.append("百叶窗罩") 


    if (re.search(word_pattern("decor cover"), title_lower) or re.search(word_pattern("panel trim"), title_lower) or re.search(word_pattern("decoration wrap"), title_lower) or re.search(word_pattern("wrap kit"), title_lower) or re.search(word_pattern("decoration cover"), title_lower) or re.search(word_pattern("console wrap"), title_lower)):
        matched_categories.append("饰件") 

    if (re.search(word_pattern("trim"), title_lower) or re.search(word_pattern("decor cover"), title_lower) or re.search(word_pattern("panel trim"), title_lower) or re.search(word_pattern("decoration wrap"), title_lower) or re.search(word_pattern("decoration cover"), title_lower) or re.search(word_pattern("console wrap"), title_lower)) and (re.search(word_pattern("interior"), title_lower)):
        matched_categories.append("内部饰件") 

    if (re.search(word_pattern("trim"), title_lower) or re.search(word_pattern("decor cover"), title_lower) or re.search(word_pattern("panel trim"), title_lower) or re.search(word_pattern("decoration wrap"), title_lower) or re.search(word_pattern("decoration cover"), title_lower) or re.search(word_pattern("console wrap"), title_lower)) and (re.search(word_pattern("exterior"), title_lower)):
        matched_categories.append("外部饰件") 

    if (re.search(word_pattern("carbon fiber"), title_lower)):
        matched_categories.append("碳纤维") 

    if (re.search(word_pattern("real carbon"), title_lower)):
        matched_categories.append("真碳") 

    if (re.search(word_pattern("door"), title_lower)) and (re.search(word_pattern("limiting"), title_lower) or re.search(word_pattern("extension"), title_lower)) and (re.search(word_pattern("straps"), title_lower) or re.search(word_pattern("strap"), title_lower)):
        matched_categories.append("门限位带") 

    if (re.search(word_pattern("floor"), title_lower)) and (re.search(word_pattern("drain"), title_lower)) and (re.search(word_pattern("plug"), title_lower) or re.search(word_pattern("plugs"), title_lower)):
        matched_categories.append("地漏塞") 

    if (re.search(word_pattern("hood"), title_lower) or re.search(word_pattern("bonnet"), title_lower)) and (re.search(word_pattern("lift supports"), title_lower) or re.search(word_pattern("struts"), title_lower) or re.search(word_pattern("support kit"), title_lower) or re.search(word_pattern("support bar"), title_lower) or re.search(word_pattern("assist"), title_lower) or re.search(word_pattern("prop rods"), title_lower) or re.search(word_pattern("hydraulic"), title_lower) or re.search(word_pattern("quicklift"), title_lower)):
        matched_categories.append("机盖液压杆")
    if (re.search(word_pattern("window"), title_lower)) and (re.search(word_pattern("lift supports"), title_lower) or re.search(word_pattern("strut"), title_lower) or re.search(word_pattern("struts"), title_lower) or re.search(word_pattern("support kit"), title_lower) or re.search(word_pattern("support bar"), title_lower) or re.search(word_pattern("assist"), title_lower) or re.search(word_pattern("prop rods"), title_lower) or re.search(word_pattern("hydraulic"), title_lower)):
        matched_categories.append("后窗液压杆")
    
    if (re.search(word_pattern("trunk"), title_lower) or re.search(word_pattern("tailgate"), title_lower)) and (re.search(word_pattern("lift supports"), title_lower) or re.search(word_pattern("strut"), title_lower) or re.search(word_pattern("struts"), title_lower) or re.search(word_pattern("support kit"), title_lower) or re.search(word_pattern("support bar"), title_lower) or re.search(word_pattern("assist"), title_lower) or re.search(word_pattern("prop rods"), title_lower) or re.search(word_pattern("hydraulic"), title_lower)):
        matched_categories.append("尾门液压杆")


    
    if (re.search(word_pattern("rear"), title_lower)) and (re.search(word_pattern("dual"), title_lower)) and (re.search(word_pattern("cup holder"), title_lower)):
        matched_categories.append("后排过桥水杯座")
    if (re.search(word_pattern("cup holder"), title_lower) or re.search(word_pattern("cupholder"), title_lower)) and (not re.search(word_pattern("coaster"), title_lower)) and (not re.search(word_pattern("liner"), title_lower)) and (not re.search(word_pattern("liners"), title_lower)):
        matched_categories.append("水杯座")

    if (re.search(word_pattern("cup"), title_lower)) and (re.search(word_pattern("coaster"), title_lower)):
        matched_categories.append("杯垫")


    # 标记照明类商品名称

    if (re.search(word_pattern("footwell"), title_lower) or re.search(word_pattern("foot well"), title_lower) or re.search(word_pattern("foot-well"), title_lower)) and (re.search(word_pattern("lighting"), title_lower) or re.search(word_pattern("light"), title_lower) or re.search(word_pattern("lights"), title_lower)):
        matched_categories.append("脚窝灯")
    if (re.search(word_pattern("cargo"), title_lower) or re.search(word_pattern("trunk"), title_lower)) and (re.search(word_pattern("lamp"), title_lower) or re.search(word_pattern("light"), title_lower) or re.search(word_pattern("lights"), title_lower) or re.search(word_pattern("lamps"), title_lower)):
        matched_categories.append("后舱灯")

    if (re.search(word_pattern("fog light"), title_lower) or re.search(word_pattern("fog lights"), title_lower) or re.search(word_pattern("fog bumper lamps"), title_lower) or re.search(word_pattern("fog lamps"), title_lower)):
        matched_categories.append("雾灯")
    if (re.search(word_pattern("daytime"), title_lower) or re.search(word_pattern("day"), title_lower)) and (re.search(word_pattern("running light"), title_lower) or re.search(word_pattern("running lights"), title_lower) or re.search(word_pattern("running lamp"), title_lower) or re.search(word_pattern("running lamps"), title_lower)):
        matched_categories.append("日行灯")
    if (re.search(word_pattern("puddle lights"), title_lower) or re.search(word_pattern("puddle light"), title_lower) or re.search(word_pattern("welcome lights"), title_lower) or re.search(word_pattern("welcome light"), title_lower) or re.search(word_pattern("door projection lights"), title_lower)):
        matched_categories.append("水坑灯")
    if (re.search(word_pattern("light bars"), title_lower) or re.search(word_pattern("light bar"), title_lower)):
        matched_categories.append("灯条")
    if (re.search(word_pattern("light covers"), title_lower) or re.search(word_pattern("light cover"), title_lower) or re.search(word_pattern("light guard"), title_lower) or re.search(word_pattern("light guards"), title_lower) or re.search(word_pattern("lamp covers"), title_lower) or re.search(word_pattern("lamp cover"), title_lower) or re.search(word_pattern("lamp guard"), title_lower) or re.search(word_pattern("lamp guards"), title_lower)) :
        matched_categories.append("灯罩")

    if (re.search(word_pattern("trail sight"), title_lower) or re.search(word_pattern("trail sights"), title_lower)) and (re.search(word_pattern("lights"), title_lower) or re.search(word_pattern("light"), title_lower)):
        matched_categories.append("机盖把手灯")

    if (re.search(word_pattern("headlight"), title_lower) or re.search(word_pattern("headlights"), title_lower) or re.search(word_pattern("head light"), title_lower) or re.search(word_pattern("head lights"), title_lower) or re.search(word_pattern("headlamp"), title_lower) or re.search(word_pattern("headlamps"), title_lower)):
        matched_categories.append("大灯")
    if (re.search(word_pattern("tail lights"), title_lower) or re.search(word_pattern("tail light"), title_lower) or re.search(word_pattern("rear lamps"), title_lower) or re.search(word_pattern("window lights"), title_lower)):
        matched_categories.append("尾灯")


    if (re.search(word_pattern("marker lights"), title_lower) or re.search(word_pattern("signal lights"), title_lower) or re.search(word_pattern("signal light"), title_lower)):
        matched_categories.append("信号灯")


    if (re.search(word_pattern("brake"), title_lower)) and (re.search(word_pattern("lights"), title_lower) or re.search(word_pattern("light"), title_lower) or re.search(word_pattern("lamp"), title_lower) or re.search(word_pattern("lamps"), title_lower)):
        matched_categories.append("刹车灯")
    if (re.search(word_pattern("grille lamps"), title_lower) or re.search(word_pattern("grille light"), title_lower) or re.search(word_pattern("grille lights"), title_lower)):
        matched_categories.append("中网小黄灯")
    if (re.search(word_pattern("front"), title_lower) or re.search(word_pattern("rear"), title_lower) or re.search(word_pattern("interior"), title_lower)) and (re.search(word_pattern("ceiling lights"), title_lower) or re.search(word_pattern("ceiling light"), title_lower) or re.search(word_pattern("reading lights"), title_lower) or re.search(word_pattern("dome lights"), title_lower) or re.search(word_pattern("dome light"), title_lower) or re.search(word_pattern("roof map light"), title_lower)):
        matched_categories.append("阅读灯/内顶灯")

    if (re.search(word_pattern("interior"), title_lower)) and (re.search(word_pattern("light"), title_lower) or re.search(word_pattern("lights"), title_lower) or re.search(word_pattern("lighting"), title_lower) or re.search(word_pattern("bulb"), title_lower) or re.search(word_pattern("bulbs"), title_lower)) and (re.search(word_pattern("kit"), title_lower) or re.search(word_pattern("kits"), title_lower)):
        matched_categories.append("内饰灯套装")



    # 将所有匹配的类别用“+”符号连接
    return '+'.join(matched_categories) if matched_categories else ""


# 在文档2中添加一列用于标注
df2['商品名称'] = df2.apply(annotate_product, axis=1)

# 保存带有标注的文档2
df2.to_excel('maverick-2024年1月-all（标注车型）（标注产品名称）.xlsx', index=False)
